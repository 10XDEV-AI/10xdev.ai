# %%
import pandas as pd
df = pd.read_csv('code_search_embeddings.csv')

# %%
display(df.head())
# Out:
#      filepath BlockStartStop  \
# 0  index.html         (0, 3)
# 1  index.html        (4, 16)
# 2  index.html       (17, 32)
# 3   style.css         (0, 5)
# 4   style.css        (6, 16)
#
#                                                 Code  \
# 0              <!DOCTYPE html>\n<html lang="en">\n\n
# 1  \n<head>\n  <meta charset="UTF-8">\n  <meta na...
# 2    <h1 id="login-header">Login</h1>\n\n  <div i...
# 3                   \nhtml {\n  height: 100%;\n}\n\n
# 4  body {\n  height: 100%;\n  margin: 0;\n  font-...
#
#                                       code_embedding
# 0  [-0.00971243530511856, 0.009902609512209892, -...
# 1  [-0.005401600617915392, 0.02604750171303749, 0...
# 2  [-0.008563509210944176, 0.026531588286161423, ...
# 3  [-0.0001689222699496895, 0.008139222860336304,...
# 4  [-0.010126542299985886, 0.022328712046146393, ...

# %%
print(len(df.iloc[0]['code_embedding']))
# Out:
# 34391

# %%
for i in df['code_embedding']:
    i = [float(x) for x in i[1:-1].split(",")]

# %%
print(i)
# Out:
# [-0.01609336957335472, -0.003941104281693697, -0.028239307925105095, -0.032616905868053436, -0.015372203662991524, 0.013790701515972614, -0.025177517905831337, -0.019952233880758286, 0.0018930584192276, -0.011949832551181316, 0.02367192879319191, -0.008394614793360233, 0.0031013262923806906, -0.008211161009967327, -0.004665432032197714, -0.022254902869462967, 0.008976607583463192, -0.015106511302292347, 0.014954687096178532, -0.037475280463695526, -0.015941545367240906, 0.00417832937091589, 0.008280746638774872, -0.0021302837412804365, -0.03491957485675812, -0.02740427479147911, -0.0012557129375636578, -0.02621498517692089, 0.020331794396042824, -5.2337847591843456e-05, 0.006398758850991726, 0.001129192765802145, -0.029858766123652458, -0.0004914518794976175, -0.006000220309942961, 0.008685611188411713, -0.0027375807985663414, -0.02839113213121891, 0.014258826151490211, -0.021306000649929047, 0.016207236796617508, -0.005060807801783085, -0.0025968269910663366, 0.007148391101509333, -
# ...
