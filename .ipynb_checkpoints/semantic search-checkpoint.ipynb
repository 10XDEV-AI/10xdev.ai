# %%
import openai
import os
import pandas as pd

text_file = open("API_key.txt", "r")

#read whole file to a string
openai.api_key =  text_file.read()

#close file
text_file.close()


split_files = []

def split_file_by_character(filename, character):
    with open(filename, 'r') as f:
        lines = f.readlines()

    start_line = 0
    prev_end_line = -1
    for i, line in enumerate(lines):
        if character in line:
            prev_end_line = i
            extracted_lines = lines[start_line:prev_end_line]

            # join the extracted lines into a string
            extracted_text = "".join(extracted_lines)
            if extracted_text != "":
                split_files.append([filename,(start_line,prev_end_line),extracted_text])
            #print(filename)
            start_line = i 
    
    extracted_lines = lines[prev_end_line+1:len(lines)]
    # join the extracted lines into a string
    extracted_text = "".join(extracted_lines)
    split_files.append([filename,(prev_end_line+1,len(lines)),extracted_text])
    
    return 


file_paths_details = [
    "index.html",
    "style.css",
    "login-page.js"
]

comment_chars = [
    "<!-",
    "/*",
    "//"
]

for i in range(0,len(file_paths_details)):
        parts = split_file_by_character(file_paths_details[i],comment_chars[i])
        

print("Total number of functions extracted:", len(split_files))

df = pd.DataFrame(split_files)
df.columns = ["filepath","BlockStartStop","Code"]
display(df)
# Out:
# Total number of functions extracted: 10
#         filepath BlockStartStop  \
# 0     index.html         (0, 3)
# 1     index.html        (3, 16)
# 2     index.html       (16, 23)
# 3     index.html       (24, 33)
# 4      style.css         (0, 5)
# 5      style.css        (5, 16)
# 6      style.css       (16, 28)
# 7      style.css       (28, 54)
# 8      style.css       (55, 86)
# 9  login-page.js        (1, 17)
#
#                                                 Code
# 0              <!DOCTYPE html>\n<html lang="en">\n\n
# 1  <!- File References ->\n\n<head>\n  <meta char...
# 2  <!- Login Page inputs ->\n  <h1 id="login-head...
# 3    <form id="login-form">\n    <input type="tex...
# 4  /*  Page Styles */\nhtml {\n  height: 100%;\n}...
# 5  /*  Body Styles */\nbody {\n  height: 100%;\n ...
# 6  /* Holder for login items*/\n#main-holder {\n ...
# 7  /*  Login Error Message Styles */\n#login-erro...
# 8  #login-form {\n  align-self: flex-start;\n  di...
# 9  const loginForm = document.getElementById("log...

# %%
def get_embedding(task):
    response = openai.Embedding.create(
            input=task,
            model="text-embedding-ada-002"
        )
    return response['data'][0]['embedding']

df['code_embedding'] = df['Code'].apply(lambda x: get_embedding(x))
df.to_csv("code_search_openai-python.csv", index=False)

# %%
display(df)
# Out:
#         filepath BlockStartStop  \
# 0     index.html         (0, 3)
# 1     index.html        (3, 16)
# 2     index.html       (16, 23)
# 3     index.html       (24, 33)
# 4      style.css         (0, 5)
# 5      style.css        (5, 16)
# 6      style.css       (16, 28)
# 7      style.css       (28, 54)
# 8      style.css       (55, 86)
# 9  login-page.js        (1, 17)
#
#                                                 Code  \
# 0              <!DOCTYPE html>\n<html lang="en">\n\n
# 1  <!- File References ->\n\n<head>\n  <meta char...
# 2  <!- Login Page inputs ->\n  <h1 id="login-head...
# 3    <form id="login-form">\n    <input type="tex...
# 4  /*  Page Styles */\nhtml {\n  height: 100%;\n}...
# 5  /*  Body Styles */\nbody {\n  height: 100%;\n ...
# 6  /* Holder for login items*/\n#main-holder {\n ...
# 7  /*  Login Error Message Styles */\n#login-erro...
# 8  #login-form {\n  align-self: flex-start;\n  di...
# 9  const loginForm = document.getElementById("log...
#
#                                       code_embedding
# 0  [-0.00965159572660923, 0.009970824234187603, -...
# 1  [-0.017962129786610603, 0.020528146997094154, ...
# 2  [-0.026179300621151924, 0.02140495926141739, -...
# 3  [-0.0092928446829319, 0.022398462519049644, -0...
# 4  [0.009526420384645462, 0.023254508152604103, 0...
# 5  [-0.0069841318763792515, 0.027859142050147057,...
# 6  [-0.023229043930768967, 0.03039339929819107, 0...
# 7  [-0.024023311212658882, 0.023775789886713028, ...
# 8  [-0.02066364698112011, 0.009861316531896591, -...
# 9  [-0.01614983379840851, -0.003961518872529268, ...

# %%
import numpy 
import matplotlib
task = 'Add OTP input Placeholder'
from openai.embeddings_utils import cosine_similarity

def search_functions(df, code_query):
    embedding = get_embedding(code_query)
    df['similarities'] = df.code_embedding.apply(lambda x: cosine_similarity(x, embedding))

    res = df.sort_values('similarities', ascending=False).head(1)
    return res

res = search_functions(df, task)

display(df)

print(res.iloc[0]['Code'])
# Out:
#         filepath BlockStartStop  \
# 0     index.html         (0, 3)
# 1     index.html        (3, 16)
# 2     index.html       (16, 23)
# 3     index.html       (24, 33)
# 4      style.css         (0, 5)
# 5      style.css        (5, 16)
# 6      style.css       (16, 28)
# 7      style.css       (28, 54)
# 8      style.css       (55, 86)
# 9  login-page.js        (1, 17)
#
#                                                 Code  \
# 0              <!DOCTYPE html>\n<html lang="en">\n\n
# 1  <!- File References ->\n\n<head>\n  <meta char...
# 2  <!- Login Page inputs ->\n  <h1 id="login-head...
# 3    <form id="login-form">\n    <input type="tex...
# 4  /*  Page Styles */\nhtml {\n  height: 100%;\n}...
# 5  /*  Body Styles */\nbody {\n  height: 100%;\n ...
# 6  /* Holder for login items*/\n#main-holder {\n ...
# 7  /*  Login Error Message Styles */\n#login-erro...
# 8  #login-form {\n  align-self: flex-start;\n  di...
# 9  const loginForm = document.getElementById("log...
#
#                                       code_embedding  similarities
# 0  [-0.00965159572660923, 0.009970824234187603, -...      0.711802
# 1  [-0.017962129786610603, 0.020528146997094154, ...      0.733849
# 2  [-0.026179300621151924, 0.02140495926141739, -...      0.759469
# 3  [-0.0092928446829319, 0.022398462519049644, -0...      0.753677
# 4  [0.009526420384645462, 0.023254508152604103, 0...      0.701533
# 5  [-0.0069841318763792515, 0.027859142050147057,...      0.710090
# 6  [-0.023229043930768967, 0.03039339929819107, 0...      0.743326
# 7  [-0.024023311212658882, 0.023775789886713028, ...      0.754526
# 8  [-0.02066364698112011, 0.009861316531896591, -...      0.781494
# 9  [-0.01614983379840851, -0.003961518872529268, ...      0.723588
# #login-form {
#   align-self: flex-start;
#   display: grid;
#   justify-items: center;
#   align-items: center;
# }
#
# .login-form-field::placeholder {
#   color: #3a3a3a;
# }
#
# .login-form-field {
#   border: none;
#   border-bottom: 1px solid #3a3a3a;
#   margin-bottom: 10px;
#   border-radius: 3px;
#   outline: none;
#   padding: 0px 0px 5px 5px;
# }
#
# #login-form-submit {
#   width: 100%;
#   padding: 7px;
#   border: none;
#   border-radius: 5px;
#   color: white;
#   font-weight: bold;
#   background-color: #D75442;
#   cursor: pointer;
#   outline: none;
# }

# %%
def replace(filename, startStop, new_code_block):
    startStop = eval(startStop)
    # Read in the contents of the file
    with open(filename, 'r') as file:
        lines = file.readlines()

    # Delete the lines between start_index and stop_index
    del lines[startStop[0]:startStop[1]+1]

    # Insert the new_code_block at start_index
    lines[startStop[0]:startStop[0]] = new_code_block

    # Write the modified contents back to the file
    with open(filename, 'w') as file:
        file.writelines(lines)

# %%
n = "<!DOCTYPE html>\n<html lang="
import fileinput
replace("test.txt", "[0,1]",n)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[38], line 3
#       1 n = "<!DOCTYPE html>\n<html lang="
#       2 import fileinput
# ----> 3 replace("test.txt", "[0,1]",n)
#
# Cell In[37], line 18, in replace(filename, startStop, new_code_block)
#      16     contents = fd.readlines()
#      17 contents.insert(startStop[0], new_code_block)  # new_string should end in a newline
# ---> 18 fd.seek(0)  # readlines consumes the iterator, so we need to start over
#      19 fd.writelines(contents)  # No need to truncate as we are increasing filesize
#      20 return
#
# ValueError: I/O operation on closed file.
