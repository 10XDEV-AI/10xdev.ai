# %%
#read OPEN AI API KEY

text_file = open("API_key.txt", "r")
openai.api_key =  text_file.read()

text_file.close()

line_embeddings = []
    
def split_file_by_line(filename):
    with open(filename, 'r') as f:
        lines = f.readlines()
        line_number = 0
        for i in lines:
            line_embeddings.append([filename,i,line_number])
            line_number +=1
    return 


blocks = []
def split_file(filename):
    with open(filename, 'r') as f:
        lines = f.readlines()

    start_line = 0
    prev_end_line = -2
    prev_line=" "
    for i, line in enumerate(lines):
        if  line[0]!=" " and (len(prev_line.replace(" ", "").replace("\t", ""))==1) :
            #print("Yes")
            #print(line)
            #print(len(line))
            stripped_line = line.replace(" ", "").replace("\t", "")
            prev_end_line = i
            extracted_lines = lines[start_line:prev_end_line]

            # join the extracted lines into a string
            extracted_text = "".join(extracted_lines)
            if extracted_text != "":
                blocks.append([filename,start_line,prev_end_line,extracted_text])
            #print(filename)
            
            start_line = i 
        prev_line=line
    extracted_lines = lines[prev_end_line:len(lines)]
    # join the extracted lines into a string
    extracted_text = "".join(extracted_lines)
    blocks.append([filename,prev_end_line,len(lines),extracted_text])

    return 


for i in range(0,len(df4)):
    if (df4.iloc[i][1]==1):
        print(df4.iloc[i][0])
        split_file_by_line(df4.iloc[i][0])
        file_extension = os.path.splitext(df4.iloc[i][0])[1]
        split_file(df4.iloc[i][0])

print("Total number of functions extracted:", len(blocks))
# Out:
# repo/index.html
# repo/login-page.js
# repo/style.css
# Total number of functions extracted: 15

# %%
df = pd.DataFrame(line_embeddings)
df2 = pd.DataFrame(blocks)
df.columns = ["filepath","Code","LineNumber"]
display(df)
df2.columns = ["filepath","BlockStart","BlockStop","Code"]
display(df2)
# Out:
#             filepath                            Code  LineNumber
# 0    repo/index.html               <!DOCTYPE html>\n           0
# 1    repo/index.html              <html lang="en">\n           1
# 2    repo/index.html                              \n           2
# 3    repo/index.html        <!- File References ->\n           3
# 4    repo/index.html                              \n           4
# ..               ...                             ...         ...
# 127   repo/style.css            font-weight: bold;\n          80
# 128   repo/style.css    background-color: #33c1ea;\n          81
# 129   repo/style.css              cursor: pointer;\n          82
# 130   repo/style.css                outline: none;\n          83
# 131   repo/style.css                             }\n          84
#
# [132 rows x 3 columns]
#               filepath  BlockStart  BlockStop  \
# 0      repo/index.html           0          3
# 1      repo/index.html           3          5
# 2      repo/index.html           5         13
# 3      repo/index.html          13         30
# 4   repo/login-page.js           0          5
# 5   repo/login-page.js           5         17
# 6       repo/style.css           0         15
# 7       repo/style.css          15         27
# 8       repo/style.css          27         36
# 9       repo/style.css          36         49
# 10      repo/style.css          49         53
# 11      repo/style.css          53         61
# 12      repo/style.css          61         65
# 13      repo/style.css          65         74
# 14      repo/style.css          74         85
#
#                                                  Code
# 0               <!DOCTYPE html>\n<html lang="en">\n\n
# 1                          <!- File References ->\n\n
# 2   <head>\n  <meta charset="UTF-8">\n  <meta name...
# 3   <body>\n<!-- Login Page Holder -->\n<main id="...
# 4   //Login Button On Click Actions\nconst loginFo...
# 5   loginButton.addEventListener("click", (e) => {...
# 6   /*  Page Styles */\nhtml {\n  height: 100%;\n}...
# 7   /* Holder for login items*/\n#main-holder {\n ...
# 8   /*  Login Error Message Styles */\n#login-erro...
# 9   #login-error-msg {\n  width: 23%;\n  text-alig...
# 10  #error-msg-second-line {\n  display: block;\n}...
# 11  /*  Login form feild styles */\n#login-form {\...
# 12  .login-form-field::placeholder {\n  color: #3a...
# 13  .login-form-field {\n  border: none;\n  border...
# 14  #login-form-submit {\n  width: 100%;\n  paddin...

# %%
#df2['Code'].apply(lambda x:print(x))
# Out:
# <!DOCTYPE html>
# <html lang="en">
#
#
# <!- File References ->
#
#
# <head>
#   <meta charset="UTF-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <title>Login</title>
#   <link rel="stylesheet" href="style.css">
#   <script defer src="login-page.js"></script>
# </head>
#
#
# <body>
# <!-- Login Page Holder -->
# <main id="main-holder">
#
#   <h1 id="login-header">Login</h1>
#   <div id="login-error-msg-holder">
#     <p id="login-error-msg">Invalid username <span id="error-msg-second-line">and/or password</span></p>
#   </div>
#   <!- Input Fields ->
#   <form id="login-form">
#     <input type="text" name="username" id="username-field" class="login-form-field" placeholder="Username">
#     <input type="password" name="password" id="password-field" class="login-form-field" placeholder="Password">
#     <input type="submit" value="Login" id="login-form-submit">
#   </form>
# </main>
# </body>
# </html>
# //Login Button On Click Actions
# const loginForm = document.getElementById("login-form");
# const loginButton = document.getElementById("login-form-submit");
# const loginErrorMsg = document.getElementById("login-error-msg");
#
#
# loginButton.addEventListener("click", (e) => {
#     e.preventDefault();
#     const username = loginForm.username.value;
#     const password = loginForm.password.value;
#
#     if (username === "user" && password === "web_dev") {
#         alert("You have successfully logged in.");
#         location.reload();
#     } else {
#         loginErrorMsg.style.opacity = 1;
#     }
# })
# /*  Page Styles */
# html {
#   height: 100%;
# }
# /*  Body Styles */
# body {
#   height: 100%;
#   margin: 0;
#   font-family: Arial, Helvetica, sans-serif;
#   display: grid;
#   justify-items: center;
#   align-items: center;
#   /*background-color: lightblue;*/
# }
#
#
# /* Holder for login items*/
# #main-holder {
#   width: 35%;
#   height: 70%;
#   display: grid;
#   justify-items: center;
#   align-items: center;
#   background-color: white;
#   border-radius: 7px;
#   box-shadow: 0px 0px 5px 2px black;
# }
#
#
# /*  Login Error Message Styles */
# #login-error-msg-holder {
#   width: 100%;
#   height: 100%;
#   display: grid;
#   justify-items: center;
#   align-items: center;
# }
#
#
# #login-error-msg {
#   width: 23%;
#   text-align: center;
#   margin: 0;
#   padding: 5px;
#   font-size: 12px;
#   font-weight: bold;
#   color: #8a0000;
#   border: 1px solid #8a0000;
#   background-color: #e58f8f;
#   opacity: 0;
# }
#
#
# #error-msg-second-line {
#   display: block;
# }
#
#
# /*  Login form feild styles */
# #login-form {
#   align-self: flex-start;
#   display: grid;
#   justify-items: center;
#   align-items: center;
# }
#
#
# .login-form-field::placeholder {
#   color: #3a3a3a;
# }
#
#
# .login-form-field {
#   border: none;
#   border-bottom: 1px solid #3a3a3a;
#   margin-bottom: 10px;
#   border-radius: 3px;
#   outline: none;
#   padding: 0px 0px 5px 5px;
# }
#
#
# #login-form-submit {
#   width: 100%;
#   padding: 7px;
#   border: none;
#   border-radius: 5px;
#   color: white;
#   font-weight: bold;
#   background-color: #33c1ea;
#   cursor: pointer;
#   outline: none;
# }
# 0     None
# 1     None
# 2     None
# 3     None
# 4     None
# 5     None
# 6     None
# 7     None
# 8     None
# 9     None
# 10    None
# 11    None
# 12    None
# 13    None
# 14    None
# Name: Code, dtype: object

# %%
df['code_embedding'] = ''
def get_embedding(task):
    time.sleep(3)
    response = openai.Embedding.create(
            input=task,
            model="text-embedding-ada-002"
        )
    return response['data'][0]['embedding']
i=0
for ind in df.index:
        i+=1
        df['code_embedding'][ind] = get_embedding(df['Code'][ind])
        print(round(100*i/len(df)))
print("Done")
df.to_csv("df.csv", index=False)
# Out:
# /var/folders/tb/txlhvbmn2fgct223r9bxzyc80000gn/T/ipykernel_20313/937155510.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['code_embedding'][ind] = get_embedding(df['Code'][ind])
# 1
# 2
# 2
# 3
# 4
# 5
# 5
# 6
# 7
# 8
# 8
# 9
# 10
# 11
# 11
# 12
# 13
# 14
# 14
# 15
# 16
# 17
# 17
# 18
# 19
# 20
# 20
# 21
# 22
# 23
# 23
# 24
# 25
# 26
# 27
# 27
# 28
# 29
# 30
# 30
# 31
# 32
# 33
# 33
# 34
# 35
# 36
# 36
# 37
# 38
# 39
# 39
# 40
# 41
# 42
# 42
# 43
# 44
# 45
# 45
# 46
# 47
# 48
# 48
# 49
# 50
# 51
# 52
# 52
# 53
# 54
# 55
# 55
# 56
# 57
# 58
# 58
# 59
# 60
# 61
# 61
# 62
# 63
# 64
# 64
# 65
# 66
# 67
# 67
# 68
# 69
# 70
# 70
# 71
# 72
# 73
# 73
# 74
# 75
# 76
# 77
# 77
# 78
# 79
# 80
# 80
# 81
# 82
# 83
# 83
# 84
# 85
# 86
# 86
# 87
# 88
# 89
# 89
# 90
# 91
# 92
# 92
# 93
# 94
# 95
# 95
# 96
# 97
# 98
# 98
# 99
# 100
# Done

# %%
df = pd.read_csv('df.csv')
df['code_embedding'] = df.code_embedding.apply(lambda x: [float(y) for y in x[1:-1].split(",")])
display(df)
# Out:
#             filepath                            Code  LineNumber  \
# 0    repo/index.html               <!DOCTYPE html>\n           0
# 1    repo/index.html              <html lang="en">\n           1
# 2    repo/index.html                              \n           2
# 3    repo/index.html        <!- File References ->\n           3
# 4    repo/index.html                              \n           4
# ..               ...                             ...         ...
# 127   repo/style.css            font-weight: bold;\n          80
# 128   repo/style.css    background-color: #33c1ea;\n          81
# 129   repo/style.css              cursor: pointer;\n          82
# 130   repo/style.css                outline: none;\n          83
# 131   repo/style.css                             }\n          84
#
#                                         code_embedding
# 0    [-0.012576594017446041, 0.0028597444761544466,...
# 1    [-0.009005490690469742, 0.010273775085806847, ...
# 2    [0.0025078936014324427, -0.018215738236904144,...
# 3    [-0.025017328560352325, -0.0020156055688858032...
# 4    [0.002500855131074786, -0.018236210569739342, ...
# ..                                                 ...
# 127  [-0.020041272044181824, 0.0022615562193095684,...
# 128  [-0.008634612895548344, -0.0038089891895651817...
# 129  [-0.035627853125333786, -0.0004950165166519582...
# 130  [-0.035233546048402786, 0.012330341152846813, ...
# 131  [-0.00411607651039958, -0.007798881735652685, ...
#
# [132 rows x 4 columns]

# %%
import numpy 
import matplotlib
task = 'When submit button is clicked redirect javascript call OTP Auth page '
from openai.embeddings_utils import cosine_similarity

def search_functions(df, code_query):
    embedding = get_embedding(code_query)
    df['similarities'] = df.code_embedding.apply(lambda x: cosine_similarity(x, embedding))
    res = df.sort_values('similarities', ascending=False).head(100)
    return res

res = search_functions(df, task)
print("Done!")
# Out:
# Done!

# %%
res = df.sort_values('similarities', ascending=False).head(round(0.05*len(df)))
display(res)
print(len(res))
# Out:
#                filepath                                               Code  \
# 25      repo/index.html      <input type="submit" value="Login" id="log...
# 32   repo/login-page.js  const loginButton = document.getElementById("l...
# 121      repo/style.css                             #login-form-submit {\n
# 22      repo/index.html                           <form id="login-form">\n
# 35   repo/login-page.js   loginButton.addEventListener("click", (e) => {\n
# 36   repo/login-page.js                              e.preventDefault();\n
# 42   repo/login-page.js                               location.reload();\n
#
#      LineNumber                                     code_embedding  \
# 25           25  [-0.020360980182886124, -0.0023479533847421408...
# 32            2  [-0.02229473926126957, -0.009531905874609947, ...
# 121          74  [-0.014604851603507996, 0.010971074923872948, ...
# 22           22  [-0.01824158988893032, 0.011540882289409637, 4...
# 35            5  [-0.02293883077800274, -0.016787413507699966, ...
# 36            6  [-0.01787797547876835, -0.028050165623426437, ...
# 42           12  [-0.01812235824763775, -0.016428161412477493, ...
#
#      similarities
# 25       0.822987
# 32       0.815763
# 121      0.804174
# 22       0.795118
# 35       0.791264
# 36       0.790852
# 42       0.790399
# 7

# %%
df3 = pd.DataFrame()

# %%
df2["Hits"] = 0
display(df2)
# Out:
#               filepath  BlockStart  BlockStop  \
# 0      repo/index.html           0          3
# 1      repo/index.html           3          5
# 2      repo/index.html           5         13
# 3      repo/index.html          13         30
# 4   repo/login-page.js           0          5
# 5   repo/login-page.js           5         17
# 6       repo/style.css           0         15
# 7       repo/style.css          15         27
# 8       repo/style.css          27         36
# 9       repo/style.css          36         49
# 10      repo/style.css          49         53
# 11      repo/style.css          53         61
# 12      repo/style.css          61         65
# 13      repo/style.css          65         74
# 14      repo/style.css          74         85
#
#                                                  Code  Hits
# 0               <!DOCTYPE html>\n<html lang="en">\n\n     0
# 1                          <!- File References ->\n\n     0
# 2   <head>\n  <meta charset="UTF-8">\n  <meta name...     0
# 3   <body>\n<!-- Login Page Holder -->\n<main id="...     0
# 4   //Login Button On Click Actions\nconst loginFo...     0
# 5   loginButton.addEventListener("click", (e) => {...     0
# 6   /*  Page Styles */\nhtml {\n  height: 100%;\n}...     0
# 7   /* Holder for login items*/\n#main-holder {\n ...     0
# 8   /*  Login Error Message Styles */\n#login-erro...     0
# 9   #login-error-msg {\n  width: 23%;\n  text-alig...     0
# 10  #error-msg-second-line {\n  display: block;\n}...     0
# 11  /*  Login form feild styles */\n#login-form {\...     0
# 12  .login-form-field::placeholder {\n  color: #3a...     0
# 13  .login-form-field {\n  border: none;\n  border...     0
# 14  #login-form-submit {\n  width: 100%;\n  paddin...     0

# %%
# group by filepath and concatenate LineNumber
df3 = res.groupby("filepath").agg({"LineNumber": list}).reset_index()

display(df3)
# Out:
#              filepath     LineNumber
# 0     repo/index.html       [25, 22]
# 1  repo/login-page.js  [2, 5, 6, 12]
# 2      repo/style.css           [74]

# %%
import numpy as np
def count_lines(filepath, start, stop):
    count = 0
    for i in df3[df3['filepath']==filepath]['LineNumber']:
        #print(i)
        for j in i:
            if(j>=start and j<stop):
                count +=1
    return count

# apply the function to each row of df2 and create a new column
df2['Hits'] = df2.apply(lambda row: count_lines(row['filepath'], row['BlockStart'], row['BlockStop']), axis=1)
display(df2)
df2.to_csv("df2.csv", index=False)
# Out:
#               filepath  BlockStart  BlockStop  \
# 0      repo/index.html           0          3
# 1      repo/index.html           3          5
# 2      repo/index.html           5         13
# 3      repo/index.html          13         30
# 4   repo/login-page.js           0          5
# 5   repo/login-page.js           5         17
# 6       repo/style.css           0         15
# 7       repo/style.css          15         27
# 8       repo/style.css          27         36
# 9       repo/style.css          36         49
# 10      repo/style.css          49         53
# 11      repo/style.css          53         61
# 12      repo/style.css          61         65
# 13      repo/style.css          65         74
# 14      repo/style.css          74         85
#
#                                                  Code  Hits
# 0               <!DOCTYPE html>\n<html lang="en">\n\n     0
# 1                          <!- File References ->\n\n     0
# 2   <head>\n  <meta charset="UTF-8">\n  <meta name...     0
# 3   <body>\n<!-- Login Page Holder -->\n<main id="...     2
# 4   //Login Button On Click Actions\nconst loginFo...     1
# 5   loginButton.addEventListener("click", (e) => {...     3
# 6   /*  Page Styles */\nhtml {\n  height: 100%;\n}...     0
# 7   /* Holder for login items*/\n#main-holder {\n ...     0
# 8   /*  Login Error Message Styles */\n#login-erro...     0
# 9   #login-error-msg {\n  width: 23%;\n  text-alig...     0
# 10  #error-msg-second-line {\n  display: block;\n}...     0
# 11  /*  Login form feild styles */\n#login-form {\...     0
# 12  .login-form-field::placeholder {\n  color: #3a...     0
# 13  .login-form-field {\n  border: none;\n  border...     0
# 14  #login-form-submit {\n  width: 100%;\n  paddin...     1

# %%
display(df2)
df2.to_csv("df2.csv", index=False)
# Out:
#               filepath  BlockStart  BlockStop  \
# 0      repo/index.html           0          3
# 1      repo/index.html           3          5
# 2      repo/index.html           5         13
# 3      repo/index.html          13         30
# 4   repo/login-page.js           0          5
# 5   repo/login-page.js           5         17
# 6       repo/style.css           0         15
# 7       repo/style.css          15         27
# 8       repo/style.css          27         36
# 9       repo/style.css          36         49
# 10      repo/style.css          49         53
# 11      repo/style.css          53         61
# 12      repo/style.css          61         65
# 13      repo/style.css          65         74
# 14      repo/style.css          74         85
#
#                                                  Code  Hits
# 0               <!DOCTYPE html>\n<html lang="en">\n\n     0
# 1                          <!- File References ->\n\n     0
# 2   <head>\n  <meta charset="UTF-8">\n  <meta name...     0
# 3   <body>\n<!-- Login Page Holder -->\n<main id="...     2
# 4   //Login Button On Click Actions\nconst loginFo...     1
# 5   loginButton.addEventListener("click", (e) => {...     3
# 6   /*  Page Styles */\nhtml {\n  height: 100%;\n}...     0
# 7   /* Holder for login items*/\n#main-holder {\n ...     0
# 8   /*  Login Error Message Styles */\n#login-erro...     0
# 9   #login-error-msg {\n  width: 23%;\n  text-alig...     0
# 10  #error-msg-second-line {\n  display: block;\n}...     0
# 11  /*  Login form feild styles */\n#login-form {\...     0
# 12  .login-form-field::placeholder {\n  color: #3a...     0
# 13  .login-form-field {\n  border: none;\n  border...     0
# 14  #login-form-submit {\n  width: 100%;\n  paddin...     1

# %%
df2 = df2.sort_values('Hits', ascending=False)   
print(df2.iloc[0])
# Out:
# filepath                                     repo/login-page.js
# BlockStart                                                    5
# BlockStop                                                    17
# Code          loginButton.addEventListener("click", (e) => {...
# Hits                                                          3
# Name: 5, dtype: object
